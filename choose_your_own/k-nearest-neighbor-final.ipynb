# %%
# !/usr/bin/env
# Out:
# TERM_PROGRAM=Apple_Terminal
# SHELL=/bin/bash
# TERM=xterm-color
# CLICOLOR=1
# TMPDIR=/var/folders/3y/4bb958t91n3709bsdhq6ymw00000gn/T/
# CONDA_SHLVL=2
# Apple_PubSub_Socket_Render=/private/tmp/com.apple.launchd.BJrDepPSR7/Render
# CONDA_PROMPT_MODIFIER=(py271)
# TERM_PROGRAM_VERSION=361.1
# TERM_SESSION_ID=A8996057-3351-4BF0-BE2A-8D7F02AAB9C6
# USER=macbook
# CONDA_EXE=/Users/macbook/anaconda3/bin/conda
# SSH_AUTH_SOCK=/private/tmp/com.apple.launchd.la9DB95STP/Listeners
# __CF_USER_TEXT_ENCODING=0x1F5:0x0:0x0
# JPY_PARENT_PID=6784
# PAGER=cat
# _CE_CONDA=
# CONDA_PREFIX_1=/Users/macbook/anaconda3
# PATH=/Users/macbook/anaconda3/envs/py271/bin:/Users/macbook/anaconda3/bin:/Users/macbook/anaconda3/condabin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin
# CONDA_PREFIX=/Users/macbook/anaconda3/envs/py271
# PWD=/Users/macbook/Documents/MisDocs/Scripts/ud120-projects/choose_your_own
# MPLBACKEND=module://ipykernel.pylab.backend_inline
# XPC_FLAGS=0x0
# _CE_M=
# XPC_SERVICE_NAME=0
# SHLVL=2
# HOME=/Users/macbook
# CONDA_PYTHON_EXE=/Users/macbook/anaconda3/bin/python
# LOGNAME=macbook
# LC_CTYPE=UTF-8
# CONDA_DEFAULT_ENV=py271
# GIT_PAGER=cat
# _=/usr/bin/env

# %%
import matplotlib.pyplot as plt
from prep_terrain_data import makeTerrainData
from class_vis import prettyPicture

features_train, labels_train, features_test, labels_test = makeTerrainData()

# %%
### the training data (features_train, labels_train) have both "fast" and "slow"
### points mixed together--separate them so we can give them different colors
### in the scatterplot and identify them visually
grade_fast = [features_train[ii][0] for ii in range(0, len(features_train)) if labels_train[ii]==0]
bumpy_fast = [features_train[ii][1] for ii in range(0, len(features_train)) if labels_train[ii]==0]
grade_slow = [features_train[ii][0] for ii in range(0, len(features_train)) if labels_train[ii]==1]
bumpy_slow = [features_train[ii][1] for ii in range(0, len(features_train)) if labels_train[ii]==1]

# %%
#### initial visualization
plt.xlim(0.0, 1.0)
plt.ylim(0.0, 1.0)
plt.scatter(bumpy_fast, grade_fast, color = "b", label="fast")
plt.scatter(grade_slow, bumpy_slow, color = "r", label="slow")
plt.legend()
plt.xlabel("bumpiness")
plt.ylabel("grade")
plt.show()

# %%
### your code here!  name your classifier object clf if you want the 
### visualization code (prettyPicture) to show you the decision boundary
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
clf = KNeighborsClassifier(n_neighbors=7)
clf.fit(features_train, labels_train) 
pred = clf.predict(features_test)
print accuracy_score(pred, labels_test)

try:
    prettyPicture(clf, features_test, labels_test)
except NameError:
    pass
# Out:
# 0.936
